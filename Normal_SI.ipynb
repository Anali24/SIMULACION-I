# %% [markdown]
# <a href="https://colab.research.google.com/github/Anali24/SIMULACION-I/blob/main/Normal_SI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ***Transfromada Inversa de una función Normal:***
#
# Karla Anali Valdez Garcia
#
# Sus características son las siguientes:
#
#
#
# •       Es una distribución simétrica.
#
# •       Es asintótica, es decir sus extremos nunca tocan el eje horizontal, cuyos valores tienden a infinito.
#
# •       En el centro de la curva se encuentran la media, la mediana y la moda.
#
# •       El área total bajo la curva representa el 100% de los casos.
#
# •       Los elementos centrales del modelo son la media y la varianza.
#
#
#
# Esta distribución es un modelo matemático que permite determinar probabilidades de ocurrencia para distintos valores de la variable.

# %%
import matplotlib.pyplot as plt
import random as rnd
import numpy as np

# %%
#Distrubución Normal
def f(a, b, n):
  lista = []  # Creamos una lista vacía para almacenar los valores de la muestra
  # Generamos n números aleatorios y aplicamos una transformación para obtener una muestra de la distribución
  for i in range(n):
    U = rnd.random()  # Generamos un número aleatorio U entre 0 y 1
    # Aplicamos la transformación para obtener valores de la distribución normal
    X = (U ** 0.135 - (1 - U) ** 0.135) / 0.1975
    lista.append(X)  # Añadimos el valor X a la lista
  return lista  # Devolvemos la lista con la muestra de la distribución normal

# %%
# Generamos una muestra de distribución normal con parámetros a=10, b=15 y n=100000
G = f(10, 15, 100000)

# Imprimimos la muestra generada
print(G)
# Out:
# [0.830444840822993, -0.5275548316075412, 0.23091674912640042, 1.1664959844473102, -0.03552622550195192, -0.22754869877299044, 0.8072946815302136, 0.24386438095995888, 0.027380934928724787, 1.408662295792361, -0.3564097545905234, 1.2349648421859536, -0.82057895575501, 0.8057760294747489, -0.26497664826670997, -0.39112015798583727, -1.4063692872016083, -0.3147079912540913, 0.6540456440277989, -0.37796593868637396, 0.252805171109817, -1.2477819117104707, -2.3357507993433417, 0.3092638581883287, -0.9256928050462083, 2.174739633535867, 1.3739345587700575, 1.5229610429308678, 0.10225030548411614, 0.6618810089165161, 0.5100847421039661, -0.5281298517068113, 1.846008583393483, 1.2113485134944517, -1.005800252646295, -0.1100357762383802, -0.7308970499003459, -0.39835458280959135, -1.0308079336152043, 0.6511062690143898, 0.8053295627342556, 0.08234970937836447, -1.5032619910897471, -0.5718552502882918, 0.04530949632082226, 0.8973509735845664, 1.0176789742788894, -1.9656533217324372, -0.7535251243143566, -1.5281158782488025, 0.2361227307681961, 1.3135693414824177, -1.2019969615536525, -0.4051419611503826, 0.6140274667258381, -0.5437929977610555, 0.3281084277903263, 0.376378735820292, 0.5633826363682646, -1.1042097210179882, -0.971502333012377, 0.5019441018054647, -0.897739325419906, 0.4026049617474731, 0.044974552779310104, 0.5240846034274265, -2.082868499148835, 0.4187038541388991, -0.9760867406954203, -0.761844015742692, 0.5394490849177557, -0.5452992515622247, -1.4909399973463908, -0.03645655364041035, -1.9254444126760568, -1.5313457331885902, 0.7285968348612826, 1.017084048457267, -0.2890465661660067, 0.0647014657511744, -0.4155648509703664, -1.2928583094747748, 2.0010598832813304, 0.6027526108683205, -0.6660532079021027, -0.7546046367830623, -1.4432133915837584, -1.0095926839330482, -0.13017452110283, 0.966192963368193, -0.6722834147317032, 0.3568746979925452, 1.7665972835007873, 0.7473692498252885, 0.8919278240274042, -1.0103897357914091, 1.2666940780997236, -1.2667734116938552, -1.4405671036153367, 1.1892649248665392, 1.8778708322692306, 0.785432792764071, -0.6011996968645978, -1.1448899985930625, 0.45791230032936303, -0.30618681988078, -1.029567903812949, 0.10306873249040824, -0.6394313514544808, -2.4373398198851453, -0.21881691926351174, -1.008190569523856, 1.4522952371923126, 0.37769368701689865, -1.131088599701642, -0.3245473376924372, -0.19260541304921042, -2.1613466167071986, 0.5652448339357911, -1.4722016791000558, -0.40642165009912895, -2.639234545726601, 0.6936485514933334, -0.5691721781140122, -0.5659835405529127, 0.9794117471634983, -1.6771616490554828, -0.36702028831123357, -0.9069820979792415, -1.712162144737991, -1.1076439662190976, -1.7193407099682392, 0.8960184638202606, -1.875934714150695, -1.3841567804152477, -0.2965932588201464, 0.01881099666211294, -1.127669052814182, -0.09648554136254482, -0.7250515881346778, -0.5519673527805934, -1.5835550160996605, 2.177364928132779, -0.34452943717472106, -0.3263462223605151, -0.271266442214266, -0.5503847147793834, -0.14082894321172462, 1.0031063976843744, -0.5992596244538735, -1.9413244414657116, 0.33156851287415756, 0.6811386837963503, 1.283946623168446, -0.22738801293923205, -1.6190569197080364, 1.2822295370459933, -1.1667281152582045, 0.9591777666717245, 0.01649228669053364, -2.129192874968555, -0.0965830553506893, -2.3217996998685067, 1.9404578185203947, -1.1779220565140092, 0.8807673955174237, -0.3951530033108004, -0.7790100477991381, -0.2983026075831702, -0.7258507139388228, -0.04935672093795193, -0.42267084030756324, -1.0922347886977335, -0.3737107443145576, 0.15533586212875913, -0.3655488417778334, 0.16817302957296545, 0.15177354957362352, 0.4083521338009277, -1.5135080799540677, -0.9533583524486232, -0.2760388795016584, -1.3581112095180934, -2.0029136199815136, 0.6221046411432771, 1.7546807811739522, 0.10109726569651871, 0.4495589551032898, -2.7524858343461687, -1.0678252530333459, 0.314505255625597, -1.5027230267119096, 0.9011870515546972, 0.31659288741613345, 2. ...

# %%
# Calculamos la media de la muestra G
media = np.mean(G)
print(media)
# Out:
# 0.0017834035323651505

# %%
# Calculamos la varianza de la muestra G
varianza = np.var(G)

# Imprimimos la varianza calculada
print(varianza)
# Out:
# 0.995860793476373

# %% [markdown]
# Gráfica :La gráfica de su función de densidad tiene una forma acampanada y es simétrica respecto de un determinado parámetro estadístico. Esta curva se conoce como campana de Gauss y es el gráfico de una función gaussiana.

# %%
# Creamos un histograma de los datos en G con 100 contenedores (bins)
plt.hist(G, bins=100)

# Añadimos etiquetas y título al gráfico
plt.xlabel('Valores de la muestra')
plt.ylabel('Frecuencia')
plt.title('Histograma de la muestra G')

# Mostramos el gráfico
plt.show()

# %%
# Creamos un gráfico de línea con los valores de la muestra G
plt.plot(G)

# Añadimos etiquetas y título al gráfico
plt.xlabel('Índice de la muestra')
plt.ylabel('Valores de la muestra')
plt.title('Gráfico de línea de la muestra G')

# Mostramos el gráfico
plt.show()

# %%
#Obtenemos distribución Acumulativa
#Obtenemos distribución Acumulativa
def cdf(G):
  n = len(G)           # Calculamos la cantidad de elementos en G
  x = np.sort(G)       # Ordenamos los elementos de G de menor a mayor
  y = np.arange(0, n) / n  # Creamos un array con valores desde 0 hasta n-1 divididos por n
  return x, y           # Devolvemos los valores ordenados x y los valores de la CDF y

# %%
# Asignamos los valores retornados por cdf(G) a las variables X y Y
X,Y =cdf(G)

# %%
# Graficamos la función de distribución acumulada (CDF) usando un gráfico de paso (step plot)
plt.step(X, Y)

# Añadimos una línea vertical en la posición de la media, con color verde
plt.axvline(media, color="green")

# Añadimos una línea horizontal en y=0.5 (CDF=0.5), con color rojo
plt.axhline(0.5, color="red")

# Mostramos el gráfico completo
plt.show()
