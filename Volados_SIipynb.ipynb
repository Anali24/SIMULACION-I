# %% [markdown]
# <a href="https://colab.research.google.com/github/Anali24/SIMULACION-I/blob/main/Volados_SIipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random as rnd
import numpy as np
import matplotlib.pyplot as plt

# %%
def volado():
        x = rnd.random()

        if 0 <= x <= 0.5:
            return "Sol"
        elif 0.5 <= x <= 1:
            return "Aguila"

# %%
volado()
# Out:
# 'Aguila'

# %%
def volados(n):
  prob=[]
  l=[]
  sol=0
  for i in range(n):
    if volado()=="Sol":
      sol +=1
      l.append(i)
      p= sol/(i+1) #probabilidad
      prob.append(p) # agragamos las probabiliades a la lista
  #grafica


  plt.plot(l,prob)
  plt.show()

  return prob

# %%
y=volados(100)
np.mean(y) # media
#ley de los grandes numeros
# Out:
# 0.49817030856772276

# %%
volados(10000000)
# Out:
# [0.3333333333333333,
#  0.2857142857142857,
#  0.2727272727272727,
#  0.3076923076923077,
#  0.35714285714285715,
#  0.375,
#  0.4117647058823529,
#  0.42105263157894735,
#  0.375,
#  0.38461538461538464,
#  0.4074074074074074,
#  0.42857142857142855,
#  0.43333333333333335,
#  0.4375,
#  0.4411764705882353,
#  0.45714285714285713,
#  0.4594594594594595,
#  0.47368421052631576,
#  0.48717948717948717,
#  0.5,
#  0.5121951219512195,
#  0.5238095238095238,
#  0.5227272727272727,
#  0.5333333333333333,
#  0.5434782608695652,
#  0.5416666666666666,
#  0.5510204081632653,
#  0.5490196078431373,
#  0.5,
#  0.5084745762711864,
#  0.5081967213114754,
#  0.5161290322580645,
#  0.515625,
#  0.5151515151515151,
#  0.5223880597014925,
#  0.5294117647058824,
#  0.5211267605633803,
#  0.5135135135135135,
#  0.52,
#  0.4878048780487805,
#  0.4880952380952381,
#  0.49411764705882355,
#  0.4942528735632184,
#  0.4782608695652174,
#  0.4838709677419355,
#  0.48936170212765956,
#  0.49473684210526314,
# ...
